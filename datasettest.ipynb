# %%
from huggingface_hub import login
login(token="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")
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from huggingface_hub import HfApi
api = HfApi()
api.upload_file(
    path_or_fileobj="./README.md",
    path_in_repo="README.md",
    repo_id="masa1357/Test-datets",
    repo_type="dataset",
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py:286, in hf_raise_for_status(response, endpoint_name)
#     285 try:
# --> 286     response.raise_for_status()
#     287 except HTTPError as e:
#
# File /usr/local/lib/python3.10/dist-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/api/datasets/masa1357/Test-datets/preupload/main
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# Cell In[5], line 3
#       1 from huggingface_hub import HfApi
#       2 api = HfApi()
# ----> 3 api.upload_file(
# ...
